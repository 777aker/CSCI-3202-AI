# %%
# Python3 program to create target string, starting from 
# random string using Genetic Algorithm 
# Author Atul Kumar on https://www.geeksforgeeks.org/genetic-algorithms/

import random 

# Number of individuals in each generation 
POPULATION_SIZE = 100

# Valid genes 
GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOP 
QRSTUVWXYZ 1234567890, .-;:_!"#%&/()=?@${[]}'''

# Target string to be generated 
TARGET = "To be or not to be."

class Individual(object): 
    ''' 
    Class representing individual in population 
    '''
    def __init__(self, chromosome): 
        self.chromosome = chromosome 
        self.fitness = self.cal_fitness() 

    @classmethod
    def mutated_genes(self): 
        ''' 
        create random genes for mutation 
        '''
        global GENES 
        gene = random.choice(GENES) 
        return gene 

    @classmethod
    def create_gnome(self): 
        ''' 
        create chromosome or string of genes 
        '''
        global TARGET 
        gnome_len = len(TARGET) 
        return [self.mutated_genes() for _ in range(gnome_len)] 

    def mate(self, par2): 
        ''' 
        Perform mating and produce new offspring 
        '''

        # chromosome for offspring 
        child_chromosome = [] 
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):	 

            # random probability 
            prob = random.random() 

            # if prob is less than 0.45, insert gene 
            # from parent 1 
            if prob < 0.45: 
                child_chromosome.append(gp1) 

            # if prob is between 0.45 and 0.90, insert 
            # gene from parent 2 
            elif prob < 0.90: 
                child_chromosome.append(gp2) 

            # otherwise insert random gene(mutate), 
            # for maintaining diversity 
            else: 
                child_chromosome.append(self.mutated_genes()) 

        # create new Individual(offspring) using 
        # generated chromosome for offspring 
        return Individual(child_chromosome) 

    def cal_fitness(self): 
        ''' 
        Calculate fittness score, it is the number of 
        characters in string which differ from target 
        string. 
        '''
        global TARGET 
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET): 
            if gs != gt: fitness+= 1
        return fitness 

# Driver code 
def main(): 
    global POPULATION_SIZE 

    #current generation 
    generation = 1

    found = False
    population = [] 

    # create initial population 
    for _ in range(POPULATION_SIZE): 
                gnome = Individual.create_gnome() 
                population.append(Individual(gnome)) 

    while not found: 

        # sort the population in increasing order of fitness score 
        population = sorted(population, key = lambda x:x.fitness) 

        # if the individual having lowest fitness score ie. 
        # 0 then we know that we have reached to the target 
        # and break the loop 
        if population[0].fitness <= 0: 
            found = True
            break

        # Otherwise generate new offsprings for new generation 
        new_generation = [ ] 

        # Perform Elitism, that mean 10% of fittest population 
        # goes to the next generation 
        s = int((10*POPULATION_SIZE)/100) 
        new_generation.extend(population[:s]) 

        # From 50% of fittest population, Individuals 
        # will mate to produce offspring 
        s = int((90*POPULATION_SIZE)/100) 
        for _ in range(s): 
            parent1 = random.choice(population[:50]) 
            parent2 = random.choice(population[:50]) 
            child = parent1.mate(parent2) 
            new_generation.append(child) 

        population = new_generation 

        print("Generation: {}\tString: {}\tFitness: {}".format(generation,"".join(population[0].chromosome),population[0].fitness)) 

        generation += 1


    print("Generation: {}\tString: {}\tFitness: {}".format(generation,"".join(population[0].chromosome),population[0].fitness)) 

if __name__ == '__main__': 
    main()
# Out:
# Generation: 1	String: TnJ lRhb:yoH s"Q5{2	Fitness: 16
# Generation: 2	String: TnJ lRhb:yoH s"Q5{2	Fitness: 16
# Generation: 3	String: oz 5D2G3 !oS(Yo0!Dh	Fitness: 15
# Generation: 4	String: oz 5D2G3 !oS(Yo0!Dh	Fitness: 15
# Generation: 5	String: jn 5V o]Wrow f0j{{7	Fitness: 14
# Generation: 6	String: jo 5D o]B oS Moj!{7	Fitness: 12
# Generation: 7	String: jo 5D o]B oS Moj!{7	Fitness: 12
# Generation: 8	String: jo 5D o]B oS Moj!{7	Fitness: 12
# Generation: 9	String: To DXmo3:}ot MoQ%!A	Fitness: 11
# Generation: 10	String: To  eRoJ yos .oQ6!A	Fitness: 10
# Generation: 11	String: To  eRoJ yos .oQ6!A	Fitness: 10
# Generation: 12	String: ToEce o;  ot doQCA7	Fitness: 9
# Generation: 13	String: ToEce o;  ot doQCA7	Fitness: 9
# Generation: 14	String: TorDeLoC yot so 6!.	Fitness: 8
# Generation: 15	String: TorDeLoC yot so 6!.	Fitness: 8
# Generation: 16	String: TorDeLoC yot so 6!.	Fitness: 8
# Generation: 17	String: To keLor rot .o 6ww	Fitness: 7
# Generation: 18	String: To keLor rot .o 6ww	Fitness: 7
# Generation: 19	String: To keLor Vot _o 6w.	Fitness: 6
# Generation: 20	String: To keLor Vot _o 6w.	Fitness: 6
# Generation: 21	String: To keLor Vot _o 6w.	Fitness: 6
# Generation: 22	String: To De or ;ot .o b].	Fitness: 4
# Generation: 23	String: To De or ;ot .o b].	Fitness: 4
# Generation: 24	String: To De or ;ot .o b].	Fitness: 4
# Generation: 25	String: To De or ;ot .o b].	Fitness: 4
# Generation: 26	String: To De or ;ot .o b].	Fitness: 4
# Generation: 27	String: To De or ;ot .o b].	Fitness: 4
# Generation: 28	String: To De or ;ot .o b].	Fitness: 4
# Generation: 29	String: To De or ;ot .o b].	Fitness: 4
# Generation: 30	String: To De or ;ot .o b].	Fitness: 4
# Generation: 31	String: To De or ;ot .o b].	Fitness: 4
# Generation: 32	String: To De or ;ot .o b].	Fitness: 4
# Generation: 33	String: To De or ;ot .o b].	Fitness: 4
# Generation: 34	String: To De or ;ot .o b].	Fitness: 4
# Generation: 35	String: To De or ;ot .o b].	Fitness: 4
# Generation: 36	String: To de or not yo bf.	Fitness: 3
# Generation: 37	String: To de or not yo bf.	Fitness: 3
# Generation: 38	String: To de or not yo bf.	Fitness: 3
# Generation: 39	String: To de or not yo bf.	Fitness: 3
# Generation: 40	String: To de or not yo bf.	Fitness: 3
# Generation: 41	String: To de or not yo bf.	Fitness: 3
# Generation: 42	String: To de or not yo bf.	Fitness: 3
# Generation: 43	String: To de or not yo bf.	Fitness: 3
# Generation: 44	String: To de or not yo bf.	Fitness: 3
# Generation: 45	String: To de or not yo bf.	Fitness: 3
# Generation: 46	String: To de or not yo bf.	Fitness: 3
# Generation: 47	String: To be or not ro bL.	Fitness: 2
# Generation: 48	String: To be or not ro bL.	Fitness: 2
# Generation: 49	String: To be or not ro bL.	Fitness: 2
# Generation: 50	String: To be or not ro bL.	Fitness: 2
# Generation: 51	String: To be or not ro bL.	Fitness: 2
# Generation: 52	String: To be or not ro bL.	Fitness: 2
# Generation: 53	String: To be or not ro bL.	Fitness: 2
# Generation: 54	String: To be or not ro bL.	Fitness: 2
# Generation: 55	String: To be or not ro bL.	Fitness: 2
# Generation: 56	String: To be or not ro bL.	Fitness: 2
# Generation: 57	String: To be or not ro bL.	Fitness: 2
# Generation: 58	String: To be or not ro bL.	Fitness: 2
# Generation: 59	String: To be or not ro bL.	Fitness: 2
# Generation: 60	String: To be or not ro bL.	Fitness: 2
# Generation: 61	String: To be or not ro bL.	Fitness: 2
# Generation: 62	String: To be or not ro bL.	Fitness: 2
# Generation: 63	String: To be or not ro bL.	Fitness: 2
# Generation: 64	String: To be or not Zo be.	Fitness: 1
# Generation: 65	String: To be or not Zo be.	Fitness: 1
# Generation: 66	String: To be or not Zo be.	Fitness: 1
# Generation: 67	String: To be or not Zo be.	Fitness: 1
# Generation: 68	String: To be or not Zo be.	Fitness: 1
# Generation: 69	String: To be or not Zo be.	Fitness: 1
# Generation: 70	String: To be or not Zo be.	Fitness: 1
# Generation: 71	String: To be or not Zo be.	Fitness: 1
# Generation: 72	String: To be or not Zo be.	Fitness: 1
# Generation: 73	String: To be or not Zo be.	Fitness: 1
# Generation: 74	String: To be or not Zo be.	Fitness: 1
# Generation: 75	String: To be or not Zo be.	Fitness: 1
# Generation: 76	String: To be or not Zo be.	Fitness: 1
# Generation: 77	String: To be or not Zo be.	Fitness: 1
# Generation: 78	String: To be or not Zo be.	Fitness: 1
# Generation: 79	String: To be or not Zo be.	Fitness: 1
# Generation: 80	String: To be or not Zo be.	Fitness: 1
# Generation: 81	String: To be or not Zo be.	Fitness: 1
# Generation: 82	String: To be or not Zo be.	Fitness: 1
# Generation: 83	String: To be or not Zo be.	Fitness: 1
# Generation: 84	String: To be or not Zo be.	Fitness: 1
# Generation: 85	String: To be or not Zo be.	Fitness: 1
# Generation: 86	String: To be or not Zo be.	Fitness: 1
# Generation: 87	String: To be or not to be.	Fitness: 0
